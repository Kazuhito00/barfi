# %% [markdown]
# # Kazuhito00/barfi パッケージをインストール

# %%
# !pip install -q "barfi[streamlit] @ git+https://github.com/Kazuhito00/barfi"

# %% [markdown]
# # リポジトリをクローン ※サンプルコードを取得

# %%
# !git clone https://github.com/Kazuhito00/barfi
# %cd barfi

# %% [markdown]
# # cloudflared インストール

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# %% [markdown]
# # サンプルスクリプト実行 & トンネル

# %%
# !streamlit run example/options_demo_app.py --server.port 8501 & \
sleep 5 & \
cloudflared tunnel --url http://localhost:8501 --no-autoupdate
